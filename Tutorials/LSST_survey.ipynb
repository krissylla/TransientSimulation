# %% [markdown]
# ### Loading the LSST survey into skysurvey
# Here we follow the skysurvey [tutorial](https://skysurvey.readthedocs.io/en/latest/howto/load_lsst.html) on how to load the survey data. The different survey strategies need to be downloaded from this [database](https://usdf-maf.slac.stanford.edu/) and placed on `TransientSimulation/Surveys/` directory. We can start with the latest version of the baseline strategy.
#
# Note: this files are pretty large so its best not to upload them to the github.

# %%
import skysurvey
